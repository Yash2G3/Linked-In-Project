# %%
import numpy as np
import pandas as pd
from numpy import nan

# %%
df=pd.read_csv("ranked_clean.csv")

# %%
df.head(20)
# Out:
#                                          App       Category  Rating  \
# 0                                   Facebook         SOCIAL     4.1
# 1                                   Facebook         SOCIAL     4.1
# 2                         WhatsApp Messenger  COMMUNICATION     4.4
# 3                         WhatsApp Messenger  COMMUNICATION     4.4
# 4                                  Instagram         SOCIAL     4.5
# 5                                  Instagram         SOCIAL     4.5
# 6                                  Instagram         SOCIAL     4.5
# 7   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 8   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 9                             Clash of Clans           GAME     4.6
# 10                            Clash of Clans           GAME     4.6
# 11                            Clash of Clans         FAMILY     4.6
# 12   Clean Master- Space Cleaner & Antivirus          TOOLS     4.7
# ...

# %%
# arranging the most downloaded  and most reviewed apps in a descending order
# this gives all the repeated names as a single app has more than 1 entry 
# so we keep only the first entry using the subset column 
# then keeping only the first occurence of that app 
df2 = df.drop_duplicates(subset=['App'])
df2
df2.to_csv('ranked_cleaned_final.csv')

# %%
res.head()
# Out:
#                                                      App            Category  \
# 0                                               Facebook              SOCIAL
# 1                                               Facebook              SOCIAL
# 2                                     WhatsApp Messenger       COMMUNICATION
# 3                                     WhatsApp Messenger       COMMUNICATION
# 4                                              Instagram              SOCIAL
# ...                                                  ...                 ...
# 10349  Eat Right Diet (by Dt Shreya's Family Diet Cli...  HEALTH_AND_FITNESS
# 10350                             Test Application DT 02      ART_AND_DESIGN
# 10351                           Santa Fe Espresso & News      FOOD_AND_DRINK
# 10352                                    Santa Fe Sentry      HOUSE_AND_HOME
# 10353                      Basic Strategy Training BJ 21                GAME
#
# ...

# %%
df2[df2['Category']=='nan']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []
